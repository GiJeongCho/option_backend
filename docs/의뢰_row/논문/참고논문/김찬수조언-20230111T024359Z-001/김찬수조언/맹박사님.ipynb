# %%
import quantstats as qs

# %%
import pandas as pd
data = pd.read_excel('맹박사님_data_20221230.xlsx')

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data = data.set_index('date')

# %%
data
# Out:
#                   st  if VIX < VIX_P  if PVOL < PVOL_MA_3W  if PVOL < HVOL  \
# date
# 2019-09-25  0.000000             0.0              0.000000        0.000000
# 2019-09-26  0.029833             0.0              0.000000        0.000000
# 2019-09-27  0.000000             0.0              0.000000        0.000000
# 2019-09-30  0.000000             0.0              0.000000        0.000000
# 2019-10-01  0.000000             0.0              0.000000        0.000000
# ...              ...             ...                   ...             ...
# 2022-10-14  0.000000             0.0              0.000000        0.000000
# 2022-10-17  0.000000             0.0              0.000000        0.000000
# 2022-10-18  0.000000             0.0              0.000000        0.000000
# 2022-10-19  0.000000             0.0              0.000000        0.000000
# 2022-10-20  0.033857             0.0              0.006086        0.017053
#
#                  ema
# date
# 2019-09-25  0.000000
# ...

# %%
data0 = data[data.columns[0]]

# %%
data1 = data[data.columns[1]]

# %%
data2 = data[data.columns[2]]

# %%
data3 = data[data.columns[3]]

# %%
data4 = data[data.columns[4]]

# %%
#양매도
qs.reports.metrics(data0, mode='full')
# Out:
#                            Strategy
# -------------------------  ----------
# Start Period               2019-09-25
# End Period                 2022-10-20
# Risk-Free Rate             0.0%
# Time in Market             17.0%
#
# Cumulative Return          -50.63%
# CAGR﹪                     -20.53%
#
# Sharpe                     0.33
# Prob. Sharpe Ratio         73.61%
# Smart Sharpe               0.33
# Sortino                    0.57
# Smart Sortino              0.57
# Sortino/√2                 0.4
# Smart Sortino/√2           0.4
# Omega                      1.25
#
# Max Drawdown               -77.44%
# Longest DD Days            665
# Volatility (ann.)          112.9%
# Calmar                     -0.27
# Skew                       9.38
# Kurtosis                   259.36
#
# Expected Daily %           -0.09%
# Expected Monthly %         -1.84%
# Expected Yearly %          -16.18%
# Kelly Criterion            12.74%
# Risk of Ruin               0.0%
# ...

# %%
a

# %%
#if VIX < VIX_P
qs.reports.metrics(data1, mode='full')
# Out:
#                            Strategy
# -------------------------  ----------
# Start Period               2019-09-25
# End Period                 2022-10-20
# Risk-Free Rate             0.0%
# Time in Market             10.0%
#
# Cumulative Return          61.0%
# CAGR﹪                     16.77%
#
# Sharpe                     0.75
# Prob. Sharpe Ratio         89.21%
# Smart Sharpe               0.75
# Sortino                    1.08
# Smart Sortino              1.07
# Sortino/√2                 0.76
# Smart Sortino/√2           0.76
# Omega                      1.58
#
# Max Drawdown               -25.21%
# Longest DD Days            210
# Volatility (ann.)          25.25%
# Calmar                     0.67
# Skew                       -1.68
# Kurtosis                   72.22
#
# Expected Daily %           0.06%
# Expected Monthly %         1.26%
# Expected Yearly %          12.64%
# Kelly Criterion            24.59%
# Risk of Ruin               0.0%
# ...

# %%
#if PVOL < PVOL_MA_3W
qs.reports.metrics(data2, mode='full')
# Out:
#                            Strategy
# -------------------------  ----------
# Start Period               2019-09-25
# End Period                 2022-10-20
# Risk-Free Rate             0.0%
# Time in Market             9.0%
#
# Cumulative Return          167.25%
# CAGR﹪                     37.72%
#
# Sharpe                     1.49
# Prob. Sharpe Ratio         100.0%
# Smart Sharpe               1.47
# Sortino                    6.21
# Smart Sortino              6.16
# Sortino/√2                 4.39
# Smart Sortino/√2           4.36
# Omega                      4.36
#
# Max Drawdown               -6.2%
# Longest DD Days            154
# Volatility (ann.)          23.51%
# Calmar                     6.09
# Skew                       16.54
# Kurtosis                   361.94
#
# Expected Daily %           0.13%
# Expected Monthly %         2.62%
# Expected Yearly %          27.86%
# Kelly Criterion            56.6%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -2.3%
# ...

# %%
#if PVOL < HVOL
qs.reports.metrics(data3, mode='full')
# Out:
#                            Strategy
# -------------------------  ----------
# Start Period               2019-09-25
# End Period                 2022-10-20
# Risk-Free Rate             0.0%
# Time in Market             11.0%
#
# Cumulative Return          -3.58%
# CAGR﹪                     -1.18%
#
# Sharpe                     0.17
# Prob. Sharpe Ratio         60.86%
# Smart Sharpe               0.17
# Sortino                    0.19
# Smart Sortino              0.19
# Sortino/√2                 0.14
# Smart Sortino/√2           0.14
# Omega                      1.1
#
# Max Drawdown               -43.23%
# Longest DD Days            372
# Volatility (ann.)          34.1%
# Calmar                     -0.03
# Skew                       -9.33
# Kurtosis                   163.59
#
# Expected Daily %           -0.0%
# Expected Monthly %         -0.1%
# Expected Yearly %          -0.91%
# Kelly Criterion            6.47%
# Risk of Ruin               0.0%
# ...

# %%
#ema
qs.reports.metrics(data4, mode='full')
# Out:
#                            Strategy
# -------------------------  ----------
# Start Period               2019-09-25
# End Period                 2022-10-20
# Risk-Free Rate             0.0%
# Time in Market             17.0%
#
# Cumulative Return          53.25%
# CAGR﹪                     14.91%
#
# Sharpe                     0.68
# Prob. Sharpe Ratio         86.02%
# Smart Sharpe               0.68
# Sortino                    0.86
# Smart Sortino              0.86
# Sortino/√2                 0.61
# Smart Sortino/√2           0.61
# Omega                      1.4
#
# Max Drawdown               -39.76%
# Longest DD Days            665
# Volatility (ann.)          25.76%
# Calmar                     0.38
# Skew                       -4.17
# Kurtosis                   62.0
#
# Expected Daily %           0.06%
# Expected Monthly %         1.13%
# Expected Yearly %          11.26%
# Kelly Criterion            20.52%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -2.6%
# ...
